# %% [markdown]
# # BigData Mart Sales Project

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
url_train='https://raw.githubusercontent.com/dsrscientist/bigdatamart_rep/master/bigdatamart_Train.csv'
url_test='https://raw.githubusercontent.com/dsrscientist/bigdatamart_rep/master/bigdatamart_Test.csv'

# %%
train=pd.read_csv(url_train)
test=pd.read_csv(url_test)

# %%
train
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998         NaN               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 3         Grocery Store           732.3800
# 4     Supermarket Type1           994.7052
# ...                 ...                ...
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700
#
# [8523 rows x 12 columns]

# %%
test
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# 1                  Dairy   87.3198            OUT017
# 2                 Others  241.7538            OUT010
# 3            Snack Foods  155.0340            OUT017
# 4                  Dairy  234.2300            OUT027
# ...                  ...       ...               ...
# 5676         Snack Foods  141.3154            OUT046
# 5677       Starchy Foods  169.1448            OUT018
# 5678  Health and Hygiene  118.7440            OUT045
# 5679              Canned  214.6218            OUT017
# 5680              Canned   79.7960            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2007         NaN               Tier 2
# 2                          1998         NaN               Tier 3
# 3                          2007         NaN               Tier 2
# 4                          1985      Medium               Tier 3
# ...                         ...         ...                  ...
# 5676                       1997       Small               Tier 1
# 5677                       2009      Medium               Tier 3
# 5678                       2002         NaN               Tier 2
# 5679                       2007         NaN               Tier 2
# 5680                       2002         NaN               Tier 2
#
#             Outlet_Type
# 0     Supermarket Type1
# 1     Supermarket Type1
# 2         Grocery Store
# 3     Supermarket Type1
# 4     Supermarket Type3
# ...                 ...
# 5676  Supermarket Type1
# 5677  Supermarket Type2
# 5678  Supermarket Type1
# 5679  Supermarket Type1
# 5680  Supermarket Type1
#
# [5681 rows x 11 columns]

# %%
print(train.shape)
print(test.shape)
# Out:
# (8523, 12)
# (5681, 11)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB

# %%
train.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %% [markdown]
# There are null values in both the dataset and in the same column, Item weight amd Outlet Size.

# %%
train.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
test.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year
# count  4705.000000      5681.000000  5681.000000                5681.000000
# mean     12.695633         0.065684   141.023273                1997.828903
# std       4.664849         0.051252    61.809091                   8.372256
# min       4.555000         0.000000    31.990000                1985.000000
# 25%       8.645000         0.027047    94.412000                1987.000000
# 50%      12.500000         0.054154   141.415400                1999.000000
# 75%      16.700000         0.093463   186.026600                2004.000000
# max      21.350000         0.323637   266.588400                2009.000000

# %%
sns.distplot(train['Item_Weight'])
# Out:
# <AxesSubplot:xlabel='Item_Weight', ylabel='Density'>

# %% [markdown]
# Let's replace the missing value in Item Weight.
#
# Since its normally distributed we will take the mean value to replace it.

# %%
train['Item_Weight'].value_counts()
# Out:
# 12.150    86
# 17.600    82
# 13.650    77
# 11.800    76
# 15.100    68
#           ..
# 7.560      2
# 9.420      1
# 5.400      1
# 6.520      1
# 7.685      1
# Name: Item_Weight, Length: 415, dtype: int64

# %%
train['Item_Weight'].mean()
# Out:
# 12.857645184136183

# %%
train['Item_Weight'].fillna((train['Item_Weight'].mean()), inplace=True)

# %%
train.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# We have replace the NaN value in Item weight now let's check how to replace the NaN in Outlet size

# %%
train['Outlet_Size'].value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %% [markdown]
# Since its an Object data we have to use mode method however Outlet Size depends on the Outlet type.
#
# So we will also see if in our data set the outlet type has any impact on outlet size

# %%
train['Outlet_Type'].value_counts()
# Out:
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %% [markdown]
# There are 4 categories in Outlet type. Let's check if any of the outlet type has any impact on the size

# %%
train.loc[train['Outlet_Type'] == 'Grocery Store']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3              FDX07    19.200000          Regular         0.000000
# 23             FDC37    12.857645          Low Fat         0.057557
# 28             FDE51     5.925000          Regular         0.161467
# 29             FDC14    12.857645          Regular         0.072222
# 30             FDV38    19.250000          Low Fat         0.170349
# ...              ...          ...              ...              ...
# 8473           DRI47    14.700000          Low Fat         0.035016
# 8480           FDQ58    12.857645          Low Fat         0.000000
# 8486           FDR20    20.000000          Regular         0.000000
# 8490           FDU44    12.857645          Regular         0.102296
# 8509           FDG45     8.100000          Low Fat         0.214306
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 3     Fruits and Vegetables  182.0950            OUT010
# 23             Baking Goods  107.6938            OUT019
# 28                    Dairy   45.5086            OUT010
# 29                   Canned   43.6454            OUT019
# 30                    Dairy   55.7956            OUT010
# ...                     ...       ...               ...
# 8473            Hard Drinks  144.3128            OUT010
# 8480            Snack Foods  154.5340            OUT019
# 8486  Fruits and Vegetables   46.4744            OUT010
# 8490  Fruits and Vegetables  162.3552            OUT019
# 8509  Fruits and Vegetables  213.9902            OUT010
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 3                          1998         NaN               Tier 3
# 23                         1985       Small               Tier 1
# 28                         1998         NaN               Tier 3
# 29                         1985       Small               Tier 1
# 30                         1998         NaN               Tier 3
# ...                         ...         ...                  ...
# 8473                       1998         NaN               Tier 3
# 8480                       1985       Small               Tier 1
# 8486                       1998         NaN               Tier 3
# 8490                       1985       Small               Tier 1
# 8509                       1998         NaN               Tier 3
#
#         Outlet_Type  Item_Outlet_Sales
# 3     Grocery Store           732.3800
# 23    Grocery Store           214.3876
# 28    Grocery Store           178.4344
# 29    Grocery Store           125.8362
# 30    Grocery Store           163.7868
# ...             ...                ...
# 8473  Grocery Store           431.4384
# 8480  Grocery Store           459.4020
# 8486  Grocery Store            45.2744
# 8490  Grocery Store           487.3656
# 8509  Grocery Store           424.7804
#
# [1083 rows x 12 columns]

# %% [markdown]
# We can see that almost all the Grocery store has 'Small' as an outlet type.
#
# Hence will update NaN with 'Small' value wherever Grocery is present as Outlet Type

# %%
train.loc[train['Outlet_Type']=='Grocery Store','Outlet_Size'] = 'Small'

# %%
train['Outlet_Size'].value_counts()
# Out:
# Small     2943
# Medium    2793
# High       932
# Name: Outlet_Size, dtype: int64

# %%
train.loc[train['Outlet_Type'] == 'Supermarket Type1']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 2              FDN15       17.500          Low Fat         0.016760
# 4              NCD19        8.930          Low Fat         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 8              FDH17       16.200          Regular         0.016687
# ...              ...          ...              ...              ...
# 8517           FDF53       20.750              reg         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 2                   Meat  141.6180            OUT049
# 4              Household   53.8614            OUT013
# 6            Snack Foods   57.6588            OUT013
# 8           Frozen Foods   96.9726            OUT045
# ...                  ...       ...               ...
# 8517        Frozen Foods  178.8318            OUT046
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 2                          1999      Medium               Tier 1
# 4                          1987        High               Tier 3
# 6                          1987        High               Tier 3
# 8                          2002         NaN               Tier 2
# ...                         ...         ...                  ...
# 8517                       1997       Small               Tier 1
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 2     Supermarket Type1          2097.2700
# 4     Supermarket Type1           994.7052
# 6     Supermarket Type1           343.5528
# 8     Supermarket Type1          1076.5986
# ...                 ...                ...
# 8517  Supermarket Type1          3608.6360
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8522  Supermarket Type1           765.6700
#
# [5577 rows x 12 columns]

# %%
train.loc[train['Outlet_Type'] == 'Supermarket Type2']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1              DRC01        5.920          Regular         0.019278
# 5              FDP36       10.395          Regular         0.000000
# 16             NCB42       11.800          Low Fat         0.008596
# 31             NCS17       18.600          Low Fat         0.080829
# 32             FDP33       18.700          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8506           DRF37       17.250          Low Fat         0.084676
# 8511           FDF05       17.500          Low Fat         0.026980
# 8515           FDH24       20.700          Low Fat         0.021518
# 8516           NCJ19       18.600          Low Fat         0.118661
# 8521           FDN46        7.210          Regular         0.145221
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 1            Soft Drinks   48.2692            OUT018
# 5           Baking Goods   51.4008            OUT018
# 16    Health and Hygiene  115.3492            OUT018
# 31    Health and Hygiene   96.4436            OUT018
# 32           Snack Foods  256.6672            OUT018
# ...                  ...       ...               ...
# 8506         Soft Drinks  263.1910            OUT018
# 8511        Frozen Foods  262.5910            OUT018
# 8515        Baking Goods  157.5288            OUT018
# 8516              Others   58.7588            OUT018
# 8521         Snack Foods  103.1332            OUT018
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 1                          2009      Medium               Tier 3
# 5                          2009      Medium               Tier 3
# 16                         2009      Medium               Tier 3
# 31                         2009      Medium               Tier 3
# 32                         2009      Medium               Tier 3
# ...                         ...         ...                  ...
# 8506                       2009      Medium               Tier 3
# 8511                       2009      Medium               Tier 3
# 8515                       2009      Medium               Tier 3
# 8516                       2009      Medium               Tier 3
# 8521                       2009      Medium               Tier 3
#
#             Outlet_Type  Item_Outlet_Sales
# 1     Supermarket Type2           443.4228
# 5     Supermarket Type2           556.6088
# 16    Supermarket Type2          1621.8888
# 31    Supermarket Type2          2741.7644
# 32    Supermarket Type2          3068.0064
# ...                 ...                ...
# 8506  Supermarket Type2          3944.8650
# 8511  Supermarket Type2          4207.8560
# 8515  Supermarket Type2          1571.2880
# 8516  Supermarket Type2           858.8820
# 8521  Supermarket Type2          1845.5976
#
# [928 rows x 12 columns]

# %%
train.loc[train['Outlet_Type'] == 'Supermarket Type3']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7              FDP10    12.857645          Low Fat         0.127470
# 18             DRI11    12.857645          Low Fat         0.034238
# 21             FDW12    12.857645          Regular         0.035400
# 36             FDV20    12.857645          Regular         0.059512
# 38             FDX10    12.857645          Regular         0.123111
# ...              ...          ...              ...              ...
# 8472           NCS41    12.857645          Low Fat         0.053185
# 8485           DRK37    12.857645          Low Fat         0.043792
# 8487           DRG13    12.857645          Low Fat         0.037006
# 8488           NCN14    12.857645          Low Fat         0.091473
# 8504           NCN18    12.857645          Low Fat         0.124111
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7               Snack Foods  107.7622            OUT027
# 18              Hard Drinks  113.2834            OUT027
# 21             Baking Goods  144.5444            OUT027
# 36    Fruits and Vegetables  128.0678            OUT027
# 38              Snack Foods   36.9874            OUT027
# ...                     ...       ...               ...
# 8472     Health and Hygiene  182.9608            OUT027
# 8485            Soft Drinks  189.0530            OUT027
# 8487            Soft Drinks  164.7526            OUT027
# 8488                 Others  184.6608            OUT027
# 8504              Household  111.7544            OUT027
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 7                          1985      Medium               Tier 3
# 18                         1985      Medium               Tier 3
# 21                         1985      Medium               Tier 3
# 36                         1985      Medium               Tier 3
# 38                         1985      Medium               Tier 3
# ...                         ...         ...                  ...
# 8472                       1985      Medium               Tier 3
# 8485                       1985      Medium               Tier 3
# 8487                       1985      Medium               Tier 3
# 8488                       1985      Medium               Tier 3
# 8504                       1985      Medium               Tier 3
#
#             Outlet_Type  Item_Outlet_Sales
# 7     Supermarket Type3          4022.7636
# 18    Supermarket Type3          2303.6680
# 21    Supermarket Type3          4064.0432
# 36    Supermarket Type3          2797.6916
# 38    Supermarket Type3           388.1614
# ...                 ...                ...
# 8472  Supermarket Type3          1653.8472
# 8485  Supermarket Type3          6261.8490
# 8487  Supermarket Type3          4111.3150
# 8488  Supermarket Type3          2756.4120
# 8504  Supermarket Type3          4138.6128
#
# [935 rows x 12 columns]

# %% [markdown]
# We can notice that only Supermarket Type 1 has mixed type whereas Type 2 and 3 has Medium.
#
# So we will check the mode of Type I and update the same in our dataset.

# %%
SM1=pd.DataFrame(data=(train.loc[train['Outlet_Type'] == 'Supermarket Type1']))

# %%
SM1
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 2              FDN15       17.500          Low Fat         0.016760
# 4              NCD19        8.930          Low Fat         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 8              FDH17       16.200          Regular         0.016687
# ...              ...          ...              ...              ...
# 8517           FDF53       20.750              reg         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 2                   Meat  141.6180            OUT049
# 4              Household   53.8614            OUT013
# 6            Snack Foods   57.6588            OUT013
# 8           Frozen Foods   96.9726            OUT045
# ...                  ...       ...               ...
# 8517        Frozen Foods  178.8318            OUT046
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 2                          1999      Medium               Tier 1
# 4                          1987        High               Tier 3
# 6                          1987        High               Tier 3
# 8                          2002         NaN               Tier 2
# ...                         ...         ...                  ...
# 8517                       1997       Small               Tier 1
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 2     Supermarket Type1          2097.2700
# 4     Supermarket Type1           994.7052
# 6     Supermarket Type1           343.5528
# 8     Supermarket Type1          1076.5986
# ...                 ...                ...
# 8517  Supermarket Type1          3608.6360
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8522  Supermarket Type1           765.6700
#
# [5577 rows x 12 columns]

# %%
SM1.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1855
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
SM1['Outlet_Size'].value_counts()
# Out:
# Small     1860
# High       932
# Medium     930
# Name: Outlet_Size, dtype: int64

# %% [markdown]
# 'Small' is the mode value present in Supermarket type 1.
#
# Hence we will update the same in our train and test data set.

# %%
train['Outlet_Size'].fillna(train['Outlet_Size'].mode()[0], inplace=True)

# %%
train['Outlet_Size'].value_counts()
# Out:
# Small     4798
# Medium    2793
# High       932
# Name: Outlet_Size, dtype: int64

# %%
train.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# Now let's fill the NaN values in test data set

# %%
test.loc[test['Outlet_Type']=='Grocery Store','Outlet_Size'] = 'Small'

# %%
test['Outlet_Size'].value_counts()
# Out:
# Small     1962
# Medium    1862
# High       621
# Name: Outlet_Size, dtype: int64

# %%
test['Outlet_Size'].fillna(test['Outlet_Size'].mode()[0], inplace=True)

# %%
test['Outlet_Size'].value_counts()
# Out:
# Small     3198
# Medium    1862
# High       621
# Name: Outlet_Size, dtype: int64

# %%
test['Item_Weight'].fillna((test['Item_Weight'].mean()), inplace=True)

# %%
test.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %%
for i in train.columns:
    print(train[i].value_counts())
    print('\n')
# Out:
# FDG33    10
# FDW13    10
# NCI54     9
# FDV38     9
# FDP25     9
#          ..
# FDO33     1
# FDQ60     1
# FDY43     1
# FDE52     1
# DRF48     1
# Name: Item_Identifier, Length: 1559, dtype: int64
#
#
# 12.857645    1463
# 12.150000      86
# 17.600000      82
# 13.650000      77
# 11.800000      76
#              ...
# 7.560000        2
# 9.420000        1
# 5.400000        1
# 6.520000        1
# 7.685000        1
# Name: Item_Weight, Length: 416, dtype: int64
#
#
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64
#
#
# 0.000000    526
# 0.076975      3
# 0.041283      2
# 0.085622      2
# 0.187841      2
#            ...
# 0.092576      1
# 0.067544      1
# 0.115168      1
# 0.146896      1
# 0.050902      1
# Name: Item_Visibility, Length: 7880, dtype: int64
#
#
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64
#
#
# 172.0422    7
# 188.1872    6
# 170.5422    6
# 109.5228    6
# 196.5084    6
#            ..
# 212.8218    1
# 190.3872    1
# 162.6868    1
# 189.1214    1
# 51.3008     1
# Name: Item_MRP, Length: 5938, dtype: int64
#
#
# OUT027    935
# OUT013    932
# OUT035    930
# OUT046    930
# OUT049    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    528
# Name: Outlet_Identifier, dtype: int64
#
#
# 1985    1463
# 1987     932
# 1999     930
# 1997     930
# 2004     930
# 2002     929
# 2009     928
# 2007     926
# 1998     555
# Name: Outlet_Establishment_Year, dtype: int64
#
#
# Small     4798
# Medium    2793
# High       932
# Name: Outlet_Size, dtype: int64
#
#
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64
#
#
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64
#
#
# 958.7520     17
# 1342.2528    16
# 1845.5976    15
# 703.0848     15
# 1278.3360    14
#              ..
# 3167.8764     1
# 2226.4352     1
# 1684.4740     1
# 1574.6170     1
# 6692.6216     1
# Name: Item_Outlet_Sales, Length: 3493, dtype: int64

# %% [markdown]
# Data in 'Item_Fat_Content' has not been updated correctly. Low Fat is updated as low fat and LF as well whereas reg is updated for Regular.

# %%
train['Item_Fat_Content'] = train['Item_Fat_Content'].replace({'LF': 'Low Fat', 'reg':'Regular','low fat':'Low Fat'})

# %% [markdown]
# The above command will replace the LF and low fat as Low Fat and reg as Regular

# %%
train['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %%
test['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    3396
# Regular    1935
# LF          206
# reg          78
# low fat      66
# Name: Item_Fat_Content, dtype: int64

# %%
test['Item_Fat_Content'] = test['Item_Fat_Content'].replace({'LF': 'Low Fat', 'reg':'Regular','low fat':'Low Fat'})

# %%
test['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    3668
# Regular    2013
# Name: Item_Fat_Content, dtype: int64

# %% [markdown]
# Item identifier has been given the unique value however we can see that the 1st 2 letter are the one which identify the item.
#
# We will keep only the 1st 2 letter from this strinng using the below command

# %%
train['Item_Identifier'] = train['Item_Identifier'].astype(str).str[:2]

# %%
train['Item_Identifier'].value_counts()
# Out:
# FD    6125
# NC    1599
# DR     799
# Name: Item_Identifier, dtype: int64

# %% [markdown]
# Now will apply the same method for test data set

# %%
test['Item_Identifier'] = test['Item_Identifier'].astype(str).str[:2]

# %%
test['Item_Identifier'].value_counts()
# Out:
# FD    4076
# NC    1087
# DR     518
# Name: Item_Identifier, dtype: int64

# %% [markdown]
# # EDA

# %%
sns.countplot(y='Item_Type',data=train)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Item_Type'>

# %% [markdown]
# From the above we can say: Fruits and vegetables are sold the maximum across the outlet, followed by Snackfood and household items. Seafood and Breakfast items were sold the least

# %%
sns.countplot(x='Outlet_Size',data=train)
# Out:
# <AxesSubplot:xlabel='Outlet_Size', ylabel='count'>

# %% [markdown]
# In terms of size in outlet, Small is dominating followed by medium.

# %%
sns.countplot(x='Outlet_Type',data=train)
# Out:
# <AxesSubplot:xlabel='Outlet_Type', ylabel='count'>

# %% [markdown]
# Supermarket Type 1 has the maximum presence. There is huge difference in other outet types.

# %%
sns.countplot(x='Outlet_Identifier',data=train)
# Out:
# <AxesSubplot:xlabel='Outlet_Identifier', ylabel='count'>

# %%
sns.countplot(x='Outlet_Location_Type',data=train)
# Out:
# <AxesSubplot:xlabel='Outlet_Location_Type', ylabel='count'>

# %%
df = train.copy()

# %%
df.groupby(['Outlet_Type','Outlet_Identifier']).agg({'Item_Outlet_Sales':np.mean}).plot.bar()
X=plt.gca().xaxis

# %% [markdown]
# Supermarket Type 3(OUT027) contributes largely towards the Sales. Rest other are close to each other but very less sale is generated from Grocery store(OUT 10 and 19)

# %%
df.groupby(['Outlet_Type','Outlet_Size']).agg({'Item_Outlet_Sales':np.mean}).plot.bar()
X=plt.gca().xaxis

# %% [markdown]
# Here again Medium size Supermarket type 3 dominates the sales chart. Other are close to each other but the least sale is generated from Small type grocery store

# %%
df.groupby(['Item_Fat_Content','Outlet_Size']).agg({'Item_Outlet_Sales':np.mean}).plot.bar()
X=plt.gca().xaxis

# %% [markdown]
# Low fat item from Small type of outlet generates the less income.

# %%
df.groupby(['Outlet_Type','Outlet_Location_Type']).agg({'Item_Outlet_Sales':np.mean}).plot.bar()
X=plt.gca().xaxis

# %% [markdown]
# Supermarket type 3 and Tier 3 location generates more sales. Grocery store in Tier 1 and 3 location are generating less sales output

# %%
df.groupby(['Outlet_Size','Outlet_Location_Type']).agg({'Item_Outlet_Sales':np.mean}).plot.bar()
X=plt.gca().xaxis

# %% [markdown]
# Medium size outlet in Tier 3 are giving good sales output whereas Small size outlet in Tier 3 are showing poor sales record

# %%
plt.scatter('Outlet_Type','Item_Outlet_Sales',data=df)

# %% [markdown]
# As confirmed earlier, Supermarket Type 3 is generating more sales whereas grocery store are contributing very less towards the sales figures

# %%
plt.scatter('Item_Type','Item_Outlet_Sales',data=df)

# %% [markdown]
# Findings from all the plots above:
#
# Medium size Supermarket type 3 outlet in Tier 3 loaction generate more revenue.
#
# Small size Grocery store in Tier 3 loaction generates less revenue

# %%
sns.pairplot(data=df)

# %%
corr=df.corr()
plt.figure(figsize=(8,8))
sns.heatmap(train.corr(),annot=True,cmap='Greens')
# Out:
# <AxesSubplot:>

# %% [markdown]
# As we can see that Outlet Sales is corealted to Item MRP and Item weight has least impact on the Sales.

# %%
df.skew()
# Out:
# Item_Weight                  0.090561
# Item_Visibility              1.167091
# Item_MRP                     0.127202
# Outlet_Establishment_Year   -0.396641
# Item_Outlet_Sales            1.177531
# dtype: float64

# %% [markdown]
# We will need to correct the skewness in Item visibility.
#
# We will apply cuberoot method to clear the skew.

# %%
df['Item_Visibility']=np.sqrt(df['Item_Visibility'])

# %%
df.skew()
# Out:
# Item_Weight                  0.090561
# Item_Visibility             -0.098056
# Item_MRP                     0.127202
# Outlet_Establishment_Year   -0.396641
# Item_Outlet_Sales            1.177531
# dtype: float64

# %% [markdown]
# Skew has been cleared from the dataset
#
# We will create the column list of all the numerical features to check for skewness and outliers

# %%
columns=['Item_Weight','Item_Visibility','Item_MRP','Outlet_Establishment_Year']

# %% [markdown]
# Checking the data distribution through Distribution plot

# %%
for i in columns:
    sns.distplot(df[i])
    plt.show()

# %% [markdown]
# Checking for outliers through box plot

# %%
for i in columns:
    sns.boxplot(df[i])
    plt.show()

# %% [markdown]
# There is not much of the outliers present in the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                8523 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
Object=['Item_Identifier','Item_Fat_Content','Item_Type','Outlet_Identifier','Outlet_Size','Outlet_Location_Type','Outlet_Type']

# %% [markdown]
# We will use LabelEncoder to change the data type

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

for i in Object:
    df[i]=le.fit_transform(df[i])

# %%
df
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                   1        9.300                 0         0.126678
# 1                   0        5.920                 1         0.138846
# 2                   1       17.500                 0         0.129461
# 3                   1       19.200                 1         0.000000
# 4                   2        8.930                 0         0.000000
# ...               ...          ...               ...              ...
# 8518                1        6.865                 0         0.238293
# 8519                1        8.380                 1         0.216754
# 8520                2       10.600                 0         0.187580
# 8521                1        7.210                 1         0.381078
# 8522                0       14.800                 0         0.211845
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# 0             4  249.8092                  9                       1999
# 1            14   48.2692                  3                       2009
# 2            10  141.6180                  9                       1999
# 3             6  182.0950                  0                       1998
# 4             9   53.8614                  1                       1987
# ...         ...       ...                ...                        ...
# 8518         13  214.5218                  1                       1987
# 8519          0  108.1570                  7                       2002
# 8520          8   85.1224                  6                       2004
# 8521         13  103.1332                  3                       2009
# 8522         14   75.4670                  8                       1997
#
#       Outlet_Size  Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0               1                     0            1          3735.1380
# 1               1                     2            2           443.4228
# 2               1                     0            1          2097.2700
# 3               2                     2            0           732.3800
# 4               0                     2            1           994.7052
# ...           ...                   ...          ...                ...
# 8518            0                     2            1          2778.3834
# 8519            2                     1            1           549.2850
# 8520            2                     1            1          1193.1136
# 8521            1                     2            2          1845.5976
# 8522            2                     0            1           765.6700
#
# [8523 rows x 12 columns]

# %% [markdown]
# Splitting our training data into input and out variable

# %%
df_x=df.drop(columns='Item_Outlet_Sales')
y=df['Item_Outlet_Sales']

# %%
df_x
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                   1        9.300                 0         0.126678
# 1                   0        5.920                 1         0.138846
# 2                   1       17.500                 0         0.129461
# 3                   1       19.200                 1         0.000000
# 4                   2        8.930                 0         0.000000
# ...               ...          ...               ...              ...
# 8518                1        6.865                 0         0.238293
# 8519                1        8.380                 1         0.216754
# 8520                2       10.600                 0         0.187580
# 8521                1        7.210                 1         0.381078
# 8522                0       14.800                 0         0.211845
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# 0             4  249.8092                  9                       1999
# 1            14   48.2692                  3                       2009
# 2            10  141.6180                  9                       1999
# 3             6  182.0950                  0                       1998
# 4             9   53.8614                  1                       1987
# ...         ...       ...                ...                        ...
# 8518         13  214.5218                  1                       1987
# 8519          0  108.1570                  7                       2002
# 8520          8   85.1224                  6                       2004
# 8521         13  103.1332                  3                       2009
# 8522         14   75.4670                  8                       1997
#
#       Outlet_Size  Outlet_Location_Type  Outlet_Type
# 0               1                     0            1
# 1               1                     2            2
# 2               1                     0            1
# 3               2                     2            0
# 4               0                     2            1
# ...           ...                   ...          ...
# 8518            0                     2            1
# 8519            2                     1            1
# 8520            2                     1            1
# 8521            1                     2            2
# 8522            2                     0            1
#
# [8523 rows x 11 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc_x=sc.fit_transform(df_x)

# %%
sc_x
# Out:
# array([[-0.17979501, -0.84187169, -0.73814723, ..., -0.66408049,
#         -1.36933384, -0.25265831],
#        [-2.09528612, -1.64170589,  1.35474328, ..., -0.66408049,
#          1.09156913,  1.00297245],
#        [-0.17979501,  1.09855449, -0.73814723, ..., -0.66408049,
#         -1.36933384, -0.25265831],
#        ...,
#        [ 1.73569609, -0.53424315, -0.73814723, ...,  0.79995418,
#         -0.13888236, -0.25265831],
#        [-0.17979501, -1.33644372,  1.35474328, ..., -0.66408049,
#          1.09156913,  1.00297245],
#        [-2.09528612,  0.45963367, -0.73814723, ...,  0.79995418,
#         -1.36933384, -0.25265831]])

# %%
x=sc_x

# %% [markdown]
# Putiing the scaled data to data frame

# %%
x=pd.DataFrame(x,columns=df_x.columns)

# %%
x
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0           -0.179795    -0.841872         -0.738147        -0.997548
# 1           -2.095286    -1.641706          1.354743        -0.884139
# 2           -0.179795     1.098554         -0.738147        -0.971612
# 3           -0.179795     1.500838          1.354743        -2.178206
# 4            1.735696    -0.929428         -0.738147        -2.178206
# ...               ...          ...               ...              ...
# 8518        -0.179795    -1.418084         -0.738147         0.042719
# 8519        -0.179795    -1.059578          1.354743        -0.158022
# 8520         1.735696    -0.534243         -0.738147        -0.429930
# 8521        -0.179795    -1.336444          1.354743         1.373504
# 8522        -2.095286     0.459634         -0.738147        -0.203778
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# 0     -0.766479  1.747454           1.507813                   0.139541
# 1      1.608963 -1.489023          -0.607071                   1.334103
# 2      0.658786  0.010040           1.507813                   0.139541
# 3     -0.291391  0.660050          -1.664513                   0.020085
# 4      0.421242 -1.399220          -1.312032                  -1.293934
# ...         ...       ...                ...                        ...
# 8518   1.371418  1.180783          -1.312032                  -1.293934
# 8519  -1.716656 -0.527301           0.802852                   0.497909
# 8520   0.183698 -0.897208           0.450371                   0.736822
# 8521   1.371418 -0.607977          -0.607071                   1.334103
# 8522   1.608963 -1.052261           1.155333                  -0.099372
#
#       Outlet_Size  Outlet_Location_Type  Outlet_Type
# 0       -0.664080             -1.369334    -0.252658
# 1       -0.664080              1.091569     1.002972
# 2       -0.664080             -1.369334    -0.252658
# 3        0.799954              1.091569    -1.508289
# 4       -2.128115              1.091569    -0.252658
# ...           ...                   ...          ...
# 8518    -2.128115              1.091569    -0.252658
# 8519     0.799954             -0.138882    -0.252658
# 8520     0.799954             -0.138882    -0.252658
# 8521    -0.664080              1.091569     1.002972
# 8522     0.799954             -1.369334    -0.252658
#
# [8523 rows x 11 columns]

# %% [markdown]
# # Model Fitting

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %% [markdown]
# We will use Linear regression model to check for the best random state to fit our training and test data

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f'At random state {i},the training accuracy is: {r2_score(y_train,pred_train)}')
    print(f'At random state {i},the testing accuracy is: {r2_score(y_test,pred_test)}')
    print('\n')
# Out:
# At random state 0,the training accuracy is: 0.5019864919429009
# At random state 0,the testing accuracy is: 0.5069656361453274
#
#
# At random state 1,the training accuracy is: 0.5036304482925784
# At random state 1,the testing accuracy is: 0.4998731503400845
#
#
# At random state 2,the training accuracy is: 0.5066773901033153
# At random state 2,the testing accuracy is: 0.48797493233499467
#
#
# At random state 3,the training accuracy is: 0.4941325368143926
# At random state 3,the testing accuracy is: 0.5372561143185033
#
#
# At random state 4,the training accuracy is: 0.5052547734666673
# At random state 4,the testing accuracy is: 0.49187958984292124
#
#
# At random state 5,the training accuracy is: 0.5051340754791745
# At random state 5,the testing accuracy is: 0.49403400850990464
#
#
# At random state 6,the training accuracy is: 0.5028722537299102
# At random state 6,the testing accuracy is: 0.5026234681538815
#
#
# At random state 7,the training accuracy is: 0.5065327977399915
# At random state 7,the testing accuracy is: 0.489774015090814
#
#
# At random state 8,the training accuracy is: 0.5002844317320059
# At random state 8,the testing accuracy is: 0.5120147087339519
#
#
# At random state 9,the training accuracy is: 0.5038230209733048
# At random state 9,the testing accuracy is: 0.49957680357170464
#
#
# At random state 10,the training accuracy is: 0.4999287085888823
# At random state 10,the testing accuracy is: 0.5147845225914702
#
#
# At random state 11,the training accuracy is: 0.5090943987140155
# At random state 11,the testing accuracy is: 0.47793498915396593
#
#
# At random state 12,the training accuracy is: 0.5005788484119087
# At random state 12,the testing accuracy is: 0.5124521926984551
#
#
# At random state 13,the training accuracy is: 0.5038395363741699
# At random state 13,the testing accuracy is: 0.4990625150672373
#
#
# At random state 14,the training accuracy is: 0.5025287544657838
# At random state 14,the testing accuracy is: 0.504990058014126
#
#
# At random state 15,the training accuracy is: 0.49925326947291937
# At random state 15,the testing accuracy is: 0.5153533094742759
#
#
# At random state 16,the training accuracy is: 0.5034796723923594
# At random state 16,the testing accuracy is: 0.4994412176245391
#
#
# At random state 17,the training accuracy is: 0.5010383779517812
# At random state 17,the testing accuracy is: 0.5109192944632835
#
#
# At random state 18,the training accuracy is: 0.504486857567265
# At random state 18,the testing accuracy is: 0.4970370581327851
#
#
# At random state 19,the training accuracy is: 0.5052360093208513
# At random state 19,the testing accuracy is: 0.4939470754785944
#
#
# At random state 20,the training accuracy is: 0.5011812876787142
# At random state 20,the testing accuracy is: 0.509780327555104
#
#
# At random state 21,the training accuracy is: 0.5011590044480306
# At random state 21,the testing accuracy is: 0.5105875157048603
#
#
# At random state 22,the training accuracy is: 0.5055930670953754
# At random state 22,the testing accuracy is: 0.49281335955996175
#
#
# At random state 23,the training accuracy is: 0.5046486970414369
# At random state 23,the testing accuracy is: 0.4957062754105255
#
#
# At random state 24,the training accuracy is: 0.5072788309404234
# At random state 24,the testing accuracy is: 0.4841946664182559
#
#
# At random state 25,the training accuracy is: 0.5063676785483628
# At random state 25,the testing accuracy is: 0.4898388412223643
#
#
# At random state 26,the training accuracy is: 0.49981159646875795
# At random state 26,the testing accuracy is: 0.5144886224649268
#
#
# At random state 27,the training accuracy is: 0.5057249797812877
# At random state 27,the testing accuracy is: 0.4919829128205365
#
#
# At random state 28,the training accuracy is: 0.49934472166507604
# At random state 28,the testing accuracy is: 0.5168166548349096
#
#
# At random state 29,the training accuracy is: 0.5053214421991719
# At random state 29,the testing accuracy is: 0.49310100673095814
#
#
# At random state 30,the training accuracy is: 0.5060765618945903
# At random state 30,the testing accuracy is: 0.4911993827977138
#
#
# At random state 31,the training accuracy is: 0.4994372042270683
# At random state 31,the testing accuracy is: 0.5170235376719465
#
#
# At random state 32,the training accuracy is: 0.5040536528838948
# At random state 32,the testing accuracy is: 0.4982909332343227
#
#
# At random state 33,the training accuracy is: 0.5033279293465781
# At random state 33,the testing accuracy is: 0.5005085125484171
#
#
# At random state 34,the training accuracy is: 0.5048114383430127
# At random state 34,the testing accuracy is: 0.4947599247149853
#
#
# At random state 35,the training accuracy is: 0.5055686572703882
# At random state 35,the testing accuracy is: 0.49246949774786597
#
#
# At random state 36,the training accuracy is: 0.5074690352963384
# At random state 36,the testing accuracy is: 0.48171912769011904
#
#
# At random state 37,the training accuracy is: 0.5095428839226958
# At random state 37,the testing accuracy is: 0.47400424082862647
#
#
# At random state 38,the training accuracy is: 0.5098185944192538
# At random state 38,the testing accuracy is: 0.47505837765874026
#
#
# At random state 39,the training accuracy is: 0.4990767022671152
# At random state 39,the testing accuracy is: 0.5173684242589542
#
#
# At random state 40,the training accuracy is: 0.5012733287440574
# At random state 40,the testing accuracy is: 0.5086482922322926
#
#
# At random state 41,the training accuracy is: 0.5113290351173531
# At random state 41,the testing accuracy is: 0.4706503532476173
#
#
# At random state 42,the training accuracy is: 0.4988249549149302
# At random state 42,the testing accuracy is: 0.5192200488123146
#
#
# At random state 43,the training accuracy is: 0.5057036623718942
# At random state 43,the testing accuracy is: 0.49039223412755906
#
#
# At random state 44,the training accuracy is: 0.5006873157303411
# At random state 44,the testing accuracy is: 0.5121550828830801
#
#
# At random state 45,the training accuracy is: 0.502377518704755
# At random state 45,the testing accuracy is: 0.5048230681221997
#
#
# At random state 46,the training accuracy is: 0.5053385143297613
# At random state 46,the testing accuracy is: 0.4926962237929112
#
#
# At random state 47,the training accuracy is: 0.505401758914374
# At random state 47,the testing accuracy is: 0.49310190620369687
#
#
# At random state 48,the training accuracy is: 0.504206975241906
# At random state 48,the testing accuracy is: 0.49814776090918
#
#
# At random state 49,the training accuracy is: 0.5011938396100485
# At random state 49,the testing accuracy is: 0.5091490827167976
#
#
# At random state 50,the training accuracy is: 0.5025804919624208
# At random state 50,the testing accuracy is: 0.504556508409139
#
#
# At random state 51,the training accuracy is: 0.5095359060150303
# At random state 51,the testing accuracy is: 0.4753291735122256
#
#
# At random state 52,the training accuracy is: 0.5045158437783406
# At random state 52,the testing accuracy is: 0.4961535251561996
#
#
# At random state 53,the training accuracy is: 0.5025286112218343
# At random state 53,the testing accuracy is: 0.5042015416483975
#
#
# At random state 54,the training accuracy is: 0.4989850491383323
# At random state 54,the testing accuracy is: 0.5169288640462313
#
#
# At random state 55,the training accuracy is: 0.5049962406744809
# At random state 55,the testing accuracy is: 0.4947130062338516
#
#
# At random state 56,the training accuracy is: 0.5105722728452227
# At random state 56,the testing accuracy is: 0.4743797332301707
#
#
# At random state 57,the training accuracy is: 0.5051170723093046
# At random state 57,the testing accuracy is: 0.49373194963664735
#
#
# At random state 58,the training accuracy is: 0.5060014256696387
# At random state 58,the testing accuracy is: 0.48927756904319175
#
#
# At random state 59,the training accuracy is: 0.5049337477058382
# At random state 59,the testing accuracy is: 0.49400092863361333
#
#
# At random state 60,the training accuracy is: 0.5014282736944791
# At random state 60,the testing accuracy is: 0.5083697255485031
#
#
# At random state 61,the training accuracy is: 0.5092602632254775
# At random state 61,the testing accuracy is: 0.47585978150245933
#
#
# At random state 62,the training accuracy is: 0.4975285357202526
# At random state 62,the testing accuracy is: 0.5236583670592567
#
#
# At random state 63,the training accuracy is: 0.4974802868569954
# At random state 63,the testing accuracy is: 0.5256152490020096
#
#
# At random state 64,the training accuracy is: 0.5078737505235191
# At random state 64,the testing accuracy is: 0.4831573335998661
#
#
# At random state 65,the training accuracy is: 0.5017040315897946
# At random state 65,the testing accuracy is: 0.5069393124479762
#
#
# At random state 66,the training accuracy is: 0.5042760400308876
# At random state 66,the testing accuracy is: 0.49803299888057595
#
#
# At random state 67,the training accuracy is: 0.5017682992802489
# At random state 67,the testing accuracy is: 0.5072094525447877
#
#
# At random state 68,the training accuracy is: 0.5010324591443076
# At random state 68,the testing accuracy is: 0.50994558257815
#
#
# At random state 69,the training accuracy is: 0.5038314400431592
# At random state 69,the testing accuracy is: 0.4988764650411571
#
#
# At random state 70,the training accuracy is: 0.5001649220321416
# At random state 70,the testing accuracy is: 0.5137602137864604
#
#
# At random state 71,the training accuracy is: 0.5030686253038459
# At random state 71,the testing accuracy is: 0.5018308709890351
#
#
# At random state 72,the training accuracy is: 0.4994168195929095
# At random state 72,the testing accuracy is: 0.5170207515279042
#
#
# At random state 73,the training accuracy is: 0.5042547507489267
# At random state 73,the testing accuracy is: 0.4974153065037753
#
#
# At random state 74,the training accuracy is: 0.5085941370207238
# At random state 74,the testing accuracy is: 0.47871013362771353
#
#
# At random state 75,the training accuracy is: 0.5018174047316479
# At random state 75,the testing accuracy is: 0.5072893930889391
#
#
# At random state 76,the training accuracy is: 0.4963271189698035
# At random state 76,the testing accuracy is: 0.529751617892938
#
#
# At random state 77,the training accuracy is: 0.5036638295060377
# At random state 77,the testing accuracy is: 0.4996084990764581
#
#
# At random state 78,the training accuracy is: 0.5057768693422826
# At random state 78,the testing accuracy is: 0.49131703823399564
#
#
# At random state 79,the training accuracy is: 0.4989087603025797
# At random state 79,the testing accuracy is: 0.5180968719635961
#
#
# At random state 80,the training accuracy is: 0.49832671786967375
# At random state 80,the testing accuracy is: 0.521793939025154
#
#
# At random state 81,the training accuracy is: 0.5033693240448267
# At random state 81,the testing accuracy is: 0.5015526638429294
#
#
# At random state 82,the training accuracy is: 0.5002944334527126
# At random state 82,the testing accuracy is: 0.512983492701786
#
#
# At random state 83,the training accuracy is: 0.5052326308861235
# At random state 83,the testing accuracy is: 0.4926785876387497
#
#
# At random state 84,the training accuracy is: 0.5027473856600859
# At random state 84,the testing accuracy is: 0.5024938315719303
#
#
# At random state 85,the training accuracy is: 0.5029923631037915
# At random state 85,the testing accuracy is: 0.5024174785399548
#
#
# At random state 86,the training accuracy is: 0.5033836519696817
# At random state 86,the testing accuracy is: 0.5009144124728924
#
#
# At random state 87,the training accuracy is: 0.5046862917709454
# At random state 87,the testing accuracy is: 0.4949800235893699
#
#
# At random state 88,the training accuracy is: 0.500191902738387
# At random state 88,the testing accuracy is: 0.5140672274531259
#
#
# At random state 89,the training accuracy is: 0.49789769122640415
# At random state 89,the testing accuracy is: 0.5229045163344812
#
#
# At random state 90,the training accuracy is: 0.5112196925046653
# At random state 90,the testing accuracy is: 0.4660611256767847
#
#
# At random state 91,the training accuracy is: 0.5102249590599759
# At random state 91,the testing accuracy is: 0.47284530621538223
#
#
# At random state 92,the training accuracy is: 0.5024219835599617
# At random state 92,the testing accuracy is: 0.5040530911770039
#
#
# At random state 93,the training accuracy is: 0.5021836308160725
# At random state 93,the testing accuracy is: 0.5056232778263872
#
#
# At random state 94,the training accuracy is: 0.5025105241647031
# At random state 94,the testing accuracy is: 0.5026747765857309
#
#
# At random state 95,the training accuracy is: 0.5022628475115412
# At random state 95,the testing accuracy is: 0.5057356230197687
#
#
# At random state 96,the training accuracy is: 0.5065231085183435
# At random state 96,the testing accuracy is: 0.4852861579798303
#
#
# At random state 97,the training accuracy is: 0.5022683333916984
# At random state 97,the testing accuracy is: 0.5043299103521663
#
#
# At random state 98,the training accuracy is: 0.5088836917619883
# At random state 98,the testing accuracy is: 0.47711820526577
#
#
# At random state 99,the training accuracy is: 0.49858693424765066
# At random state 99,the testing accuracy is: 0.5181988455555573

# %% [markdown]
# We will now split the data with the random_state 17 as that has given us the best accuracy on training and test data.

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=17)

# %% [markdown]
# Fitting the data to SupportVectorRegression model

# %%
from sklearn.svm import SVR
kernellist=['linear','poly','rbf']
for i in kernellist:
    sv=SVR(kernel=i)
    sv.fit(x_train,y_train)
    print(sv.score(x_train,y_train))
# Out:
# 0.4615232095866276
# 0.07045209188805646
# 0.05124790326311135

# %% [markdown]
# Fitting the data to various model and checking the accuracy

# %%
sv=SVR(kernel='poly')
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor

dt=DecisionTreeRegressor()
rf=RandomForestRegressor()
ab=AdaBoostRegressor()

model=[lr,sv,dt,rf,ab]

for m in model:
    m.fit(x_train,y_train)
    pred_train=m.predict(x_train)
    pred_test=m.predict(x_test)
    train_score=r2_score(y_train,pred_train)
    test_score=r2_score(y_test,pred_test)
    print('Accuracy of', m )
    print('Training Score', train_score)
    print('Testing Score', test_score)
    print('\n')
# Out:
# Accuracy of LinearRegression()
# Training Score 0.5010383779517812
# Testing Score 0.5109192944632835
#
#
# Accuracy of SVR(kernel='poly')
# Training Score 0.07045209188805646
# Testing Score 0.07737421370658293
#
#
# Accuracy of DecisionTreeRegressor()
# Training Score 1.0
# Testing Score 0.18728578048425237
#
#
# Accuracy of RandomForestRegressor()
# Training Score 0.9384253003168472
# Testing Score 0.5490591844356487
#
#
# Accuracy of AdaBoostRegressor()
# Training Score 0.5616871143513469
# Testing Score 0.5432552683225602

# %% [markdown]
# From the above score, Linear regression has given us the best accuracy

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score

model=(lr,sv,dt,rf,ab)
for m in model:
    score=cross_val_score(m,x,y,cv=5)
    print('Mean Accuracy of', m)
    print(score.mean())
    print('\n')
# Out:
# Mean Accuracy of LinearRegression()
# 0.5008274353653208
#
#
# Mean Accuracy of SVR(kernel='poly')
# 0.07081037872605933
#
#
# Mean Accuracy of DecisionTreeRegressor()
# 0.1468147809728944
#
#
# Mean Accuracy of RandomForestRegressor()
# 0.5474379844783973
#
#
# Mean Accuracy of AdaBoostRegressor()
# 0.4893224951690951

# %% [markdown]
# From the cross validation we can say that Linear Regression and AdaBoostRegressor work well. RFR and DTR are overfitting.

# %% [markdown]
# # Normalization and HyperTuning

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso

parameters={'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
ls=Lasso(alpha=1,random_state=0)
ls.fit(x_train,y_train)
pred_ls=ls.predict(x_test)
lss=r2_score(y_test,pred_ls)
lss
# Out:
# 0.5108794977215956

# %%
cv_score=cross_val_score(ls,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.5008584746823842

# %% [markdown]
# We got 0.51 score for training and 0.50 through cross validation from Lasso
#
# As there is not much Hyperparmters for Linear regression we will fit our Final Model

# %%
Finalmod=LinearRegression(copy_X=True, fit_intercept= True, n_jobs=None, normalize=False)
Finalmod.fit(x_train,y_train)
pred_final=Finalmod.predict(x_test)
rfs=r2_score(y_test,pred_final)
print('R2 Score', rfs*100)

rfscore=cross_val_score(Finalmod,x,y,cv=5)
rfc=rfscore.mean()
print('Cross Val score', rfc*100)
# Out:
# R2 Score 51.09192944632836
# Cross Val score 50.08274353653208

# %% [markdown]
# We have got accuracy of 51% on training and 50% on Cross validation

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_final,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual Sales',fontsize=14)
plt.ylabel('Predicted Sales',fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.show()

# %% [markdown]
# The model is performing ok as we got only 51% accuracy which not that great.

# %%
import joblib
joblib.dump(Finalmod,'BigDataMart_sales.obj')
# Out:
# ['BigDataMart_sales.obj']
